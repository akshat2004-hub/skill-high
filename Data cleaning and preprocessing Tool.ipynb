# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
data = pd.read_csv("/content/sample_data/california_housing_test.csv")
print(data.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
data.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
data.dropna(inplace=True)
print(data)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0
#
# [2878 rows x 9 columns]

# %%
data = data.drop_duplicates()
print(data)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0
#
# [2878 rows x 9 columns]

# %%
z = np.abs(stats.zscore(data.select_dtypes(include=[np.number])))
data = data[(z < 3).all(axis=1)]

# %%
data.to_csv("/content/sample_data/california_housing_test.csv", index=False)

# %%
def clean_data(file_path):
    df = pd.read_csv(file_path)
    df.drop_duplicates(inplace=True)
    df.fillna(df.mean(numeric_only=True), inplace=True)
    z = np.abs(stats.zscore(df.select_dtypes(include=[np.number])))
    df = df[(z < 3).all(axis=1)]
    df.to_csv("cleaned_data.csv", index=False)
    return df

# %%
clean_data("/content/sample_data/california_housing_test.csv")
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2872    -117.93     33.86                35.0        931.0           181.0
# 2873    -119.86     34.42                23.0       1450.0           642.0
# 2874    -118.14     34.06                27.0       5257.0          1082.0
# 2875    -119.70     36.30                10.0        956.0           201.0
# 2876    -117.12     34.10                40.0         96.0            14.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2872       516.0       174.0         5.5867            182500.0
# 2873      1258.0       607.0         1.1790            225000.0
# 2874      3496.0      1036.0         3.3906            237200.0
# 2875       693.0       220.0         2.2895             62000.0
# 2876        46.0        14.0         3.2708            162500.0
#
# [2761 rows x 9 columns]

# %%
df = clean_data("/content/sample_data/california_housing_test.csv")

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.describe()
# Out:
#          longitude     latitude  housing_median_age  total_rooms  \
# count  2761.000000  2761.000000         2761.000000  2761.000000
# mean   -119.614730    35.667993           29.535675  2241.367258
# std       1.991727     2.142821           12.268652  1243.580190
# min    -124.180000    32.560000            1.000000     6.000000
# 25%    -121.820000    33.940000           19.000000  1354.000000
# 50%    -118.520000    34.310000           30.000000  2025.000000
# 75%    -118.040000    37.700000           38.000000  2899.000000
# max    -114.490000    41.920000           52.000000  6660.000000
#
#        total_bedrooms   population   households  median_income  \
# count     2761.000000  2761.000000  2761.000000    2761.000000
# mean       463.540022  1241.673307   432.777617       3.618069
# std        248.143783   672.212738   228.964735       1.490281
# min          2.000000     5.000000     2.000000       0.499900
# 25%        285.000000   768.000000   269.000000       2.517900
# 50%        422.000000  1119.000000   395.000000       3.418700
# 75%        598.000000  1632.000000   561.000000       4.512200
# max       1355.000000  3595.000000  1245.000000       8.282700
#
#        median_house_value
# count         2761.000000
# mean        198015.706628
# std         105733.609263
# min          22500.000000
# 25%         117300.000000
# 50%         174400.000000
# 75%         252400.000000
# max         500001.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2761 entries, 0 to 2876
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           2761 non-null   float64
#  1   latitude            2761 non-null   float64
#  2   housing_median_age  2761 non-null   float64
#  3   total_rooms         2761 non-null   float64
#  4   total_bedrooms      2761 non-null   float64
#  5   population          2761 non-null   float64
#  6   households          2761 non-null   float64
#  7   median_income       2761 non-null   float64
#  8   median_house_value  2761 non-null   float64
# dtypes: float64(9)
# memory usage: 215.7 KB
